# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# time plot for test case1
x = [1,2,4,6,8]
y = [[0.3710737, 0.8772733, 2.5788254, 0.126268],
     [0.0589231, 0.196912, 1.4836848, 0.0852117],
     [0.037203, 0.1092261, 0.9221, 0.064155],
     [0.0306303, 0.1061576, 0.9069383, 0.0688058],
     [0.0531997, 0.0962629, 0.9344596, 0.0357405]]

fig=plt.figure(figsize=(10,8))
fig.suptitle('Tiime Consuming For Put Operation', fontsize=15)
ax = plt.subplot(111)
lineObjects = ax.plot(x, y)
ax.legend(iter(lineObjects),['PhaseConcurrentHashTable','LockFreeHashTable', 'LockBasedHashTable', 'ConcurrentHashMap(sdk1.8)'])
plt.xlabel('Threads')
plt.xticks(x)
plt.ylabel('Time (sec)')
plt.show()

# %%
# time plot for test case2
x = [1,2,4,6,8]
y = [[0.0288351, 0.044221, 0.0467913, 0.0173238],
     [0.0138314, 0.0225724, 0.0394027, 0.0190825],
     [0.0181118, 0.0234405, 0.0303647, 0.0215071],
     [0.007747, 0.0140781, 0.0302769, 0.0059517],
     [0.0070208, 0.0363717, 0.0306154, 0.0059001]]

fig=plt.figure(figsize=(10,8))
fig.suptitle('Tiime Consuming For Remove Operation', fontsize=15)
ax = plt.subplot(111)
lineObjects = ax.plot(x, y)
ax.legend(iter(lineObjects),['PhaseConcurrentHashTable','LockFreeHashTable', 'LockBasedHashTable', 'ConcurrentHashMap(sdk1.8)'])
plt.xlabel('Threads')
plt.xticks(x)
plt.ylabel('Time (sec)')
plt.show()

# %%
# time plot for test case3
x = [1,2,4,6,8]
y = [[0.0545536, 0.0800114, 2.5030484, 0.0772115],
     [0.0210142, 0.0280646, 1.2785726, 0.0391022],
     [0.0152906, 0.0233297, 0.7157054, 0.0164082],
     [0.0150236, 0.02471, 0.59407, 0.0190511],
     [0.01316, 0.0199177, 0.5024983, 0.0169408]]

fig=plt.figure(figsize=(10,8))
fig.suptitle('Tiime Consuming For Find Operation', fontsize=15)
ax = plt.subplot(111)
lineObjects = ax.plot(x, y)
ax.legend(iter(lineObjects),['PhaseConcurrentHashTable','LockFreeHashTable', 'LockBasedHashTable', 'ConcurrentHashMap(sdk1.8)'])
plt.xlabel('Threads')
plt.xticks(x)
plt.ylabel('Time (sec)')
plt.show()

x = [1,2,4,6,8]
y = [[0.0545536, 0.0800114, 0.0772115],
     [0.0210142, 0.0280646, 0.0391022],
     [0.0152906, 0.0233297, 0.0164082],
     [0.0150236, 0.02471, 0.0190511],
     [0.01316, 0.0199177, 0.0169408]]

fig=plt.figure(figsize=(10,8))
fig.suptitle('Tiime Consuming For Find Operation', fontsize=15)
ax = plt.subplot(111)
lineObjects = ax.plot(x, y)
ax.legend(iter(lineObjects),['PhaseConcurrentHashTable','LockFreeHashTable', 'ConcurrentHashMap(sdk1.8)'])
plt.xlabel('Threads')
plt.xticks(x)
plt.ylabel('Time (sec)')
plt.show()
