# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# time plot for test case1
x = [1,2,4,6,8]
y = [[0.2210778, 0.3526426, 0.1425144, 0.0710264, 0.1306107],
     [0.0589231, 0.196912, 0.0911812, 0.1077162, 0.2212258],
     [0.037203, 0.1092261, 0.0583101, 0.064155, 0.2318937],
     [0.0306303, 0.1061576, 0.0559221, 0.0688058, 0.2338109],
     [0.0531997, 0.0962629, 0.0545371, 0.0357405, 0.2991297]]

fig=plt.figure(figsize=(10,8))
fig.suptitle('Tiime Costs For Put Operation (TEST_SIZE = 1000000)', fontsize=15)
ax = plt.subplot(111)
lineObjects = ax.plot(x, y)
ax.legend(iter(lineObjects),['PhaseConcurrentHashTable','LockFreeHashTable', 'LockBasedHashTable', 'ConcurrentHashMap(sdk1.8)', 'CuckooLockBasedHashTable'])
plt.xlabel('Threads')
plt.xticks(x)
plt.ylabel('Time (sec)')
plt.show()

# %%
# time plot for test case2
x = [1,2,4,6,8]
y = [[0.0288351, 0.044221, 0.0307097, 0.0173238, 0.0946338],
     [0.0138314, 0.0225724, 0.0264934, 0.0190825, 0.1263077],
     [0.0181118, 0.0234405, 0.0207338, 0.0215071, 0.1367688],
     [0.007747, 0.0140781, 0.0186995, 0.0059517, 0.1346654],
     [0.0070208, 0.0363717, 0.0191757, 0.0059001, 0.1400874]]

fig=plt.figure(figsize=(10,8))
fig.suptitle('Tiime Costs For Remove Operation (TEST_SIZE = 1000000)', fontsize=15)
ax = plt.subplot(111)
lineObjects = ax.plot(x, y)
ax.legend(iter(lineObjects),['PhaseConcurrentHashTable','LockFreeHashTable', 'LockBasedHashTable', 'ConcurrentHashMap(sdk1.8)', 'CuckooLockBasedHashTable'])
plt.xlabel('Threads')
plt.xticks(x)
plt.ylabel('Time (sec)')
plt.show()

# %%
# time plot for test case3
x = [1,2,4,6,8]
y = [[0.0545536, 0.0800114, 0.1236186, 0.0772115, 0.068305],
     [0.0210142, 0.0280646, 0.0667646, 0.0391022, 0.0281025],
     [0.0152906, 0.0233297, 0.0334751, 0.0164082, 0.0161157],
     [0.0150236, 0.02471, 0.0186564, 0.0190511, 0.0184209],
     [0.01316, 0.0199177, 0.0232133, 0.0169408, 0.0138658]]

fig=plt.figure(figsize=(10,8))
fig.suptitle('Tiime Costs For Find Operation (TEST_SIZE = 1000000)', fontsize=15)
ax = plt.subplot(111)
lineObjects = ax.plot(x, y)
ax.legend(iter(lineObjects),['PhaseConcurrentHashTable','LockFreeHashTable', 'LockBasedHashTable', 'ConcurrentHashMap(sdk1.8)', 'CuckooLockBasedHashTable'])
plt.xlabel('Threads')
plt.xticks(x)
plt.ylabel('Time (sec)')
plt.show()

x = [1,2,4,6,8]
y = [[0.0545536, 0.0800114, 0.0772115, 0.068305],
     [0.0210142, 0.0280646, 0.0391022, 0.0281025],
     [0.0152906, 0.0233297, 0.0164082, 0.0161157],
     [0.0150236, 0.02471, 0.0190511, 0.0184209],
     [0.01316, 0.0199177, 0.0169408, 0.0138658]]

fig=plt.figure(figsize=(10,8))
fig.suptitle('Tiime Consuming For Find Operation (TEST_SIZE = 1000000)', fontsize=15)
ax = plt.subplot(111)
lineObjects = ax.plot(x, y)
ax.legend(iter(lineObjects),['PhaseConcurrentHashTable','LockFreeHashTable', 'ConcurrentHashMap(sdk1.8)','CuckooLockBasedHashTable'])
plt.xlabel('Threads')
plt.xticks(x)
plt.ylabel('Time (sec)')
plt.show()
